# %% [markdown]
# ## Hyperparameter tuning on XGBoost & Logistics Regression on LLM embedding

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import (f1_score, accuracy_score, precision_score, 
                             recall_score, classification_report)

# %%
# --- 1. Load and Prepare the Data ---
df = pd.read_csv('../../data/tweets.csv.gz', compression="gzip")
# Keep only the relevant columns and drop rows with missing text
df = df[['airline_sentiment', 'text']].dropna()

# %%
# We will perform multiclass classification (positive, negative, neutral)
# Map the sentiment labels to numerical values for the model
df["airline_sentiment_encoded"] = df["airline_sentiment"].map({"negative": 0, "neutral": 1, "positive": 2})

# %%
# Select the features (X) and target variable (y)
X = df['text']
y = df['airline_sentiment_encoded'] # Use the encoded labels

# %%
# --- 2. Split Data for Training and Testing ---
# Split the data into training and testing sets.
# Using stratify=y ensures the proportion of each sentiment is the same in both sets.
# The random_state parameter ensures that the data is split in the same way every time.

from sklearn.model_selection import train_test_split

# Split before SMOTE
X_train, X_temp, y_train, y_temp = train_test_split(X, y, 
                                        stratify=y,            
                                        train_size=0.7, 
                                        random_state=42)
X_valid, X_test, y_valid, y_test = train_test_split(X_temp, y_temp, 
                                        stratify=y_temp,            
                                        train_size=0.5,
                                        random_state=42)

# %%
# --- 3. Generate SBERT Embeddings for train test validation split ---
# We will use a pre-trained SBERT model to convert the tweet text into numerical vectors.

import os
import pandas as pd 
from utils.prepare_llm_embedding import generate_embeddings_from_series 

# generate llm embedding for train data
EMBEDDING_TRAIN = "../../data/hyperparameter_tuning_llm_embedding_train.csv.gz"
if os.path.exists(EMBEDDING_TRAIN):
    pass
else:
    processed_text_series = pd.Series(X_train.to_list(),
                                    index=X_train.index.to_list()) 
    llm_embedding_train = generate_embeddings_from_series(processed_text_series,
                            additional_data={"encoded_sentiment": y_train.to_list()},
                            output_csv_path="../../data/hyperparameter_tuning_llm_embedding_train.csv.gz",
                            max_workers=20)
    print(llm_embedding_train)

# generate llm embedding for valid data
EMBEDDING_VALID = "../../data/hyperparamter_tuning_llm_embedding_valid.csv.gz"
if os.path.exists(EMBEDDING_VALID):
    pass
else:
    processed_text_series = pd.Series(X_valid.to_list(), 
                                    index=X_valid.index.to_list()) 
    llm_embedding_valid = generate_embeddings_from_series(processed_text_series,
                            additional_data={"encoded_sentiment": y_valid.to_list()},
                            output_csv_path="../../data/hyperparamter_tuning_llm_embedding_valid.csv.gz",
                            max_workers=20) 
    print(llm_embedding_valid)
    
# generate llm embedding for test data
EMBEDDING_TEST = "../../data/hyperparamter_tuning_llm_embedding_test.csv.gz"
if os.path.exists(EMBEDDING_TEST):
    pass
else:
    processed_text_series = pd.Series(X_test.to_list(), 
                                    index=X_test.index.to_list()) 
    llm_embedding_test = generate_embeddings_from_series(processed_text_series,
                            additional_data={"encoded_sentiment": y_test.to_list()},
                            output_csv_path="../../data/hyperparamter_tuning_llm_embedding_test.csv.gz",
                            max_workers=20)
    print(llm_embedding_test)
# Out:
# Starting embedding generation for 10248 texts. Results will be saved to ../../data/hyperparameter_tuning_llm_embedding_train.csv.gz.
# Using up to 20 concurrent API calls...
# [Thread-8984] Requesting embedding for text: "@SouthwestAir Suggestions: tell customers approxim..."
# [Thread-17588] Requesting embedding for text: "@AmericanAir - very upset with my hometown airline..."
# [Thread-15736] Requesting embedding for text: "@united There are Exit-Row window shades in approx..."
# [Thread-4180] Requesting embedding for text: "@united Hi, I am flying domestic first from SEA to..."
# [Thread-23280] Requesting embedding for text: "@AmericanAir United needs our ticket number since ..."
# [Thread-14768] Requesting embedding for text: "@AmericanAir great, thanks!..."
# [Thread-12124] Requesting embedding for text: "@united flight from vegas to houston Cancelled Fli..."
# [Thread-11164] Requesting embedding for text: "@USAirways that's who I spoke to already. We've al..."
# [Thread-19948] Requesting embedding for text: "@SouthwestAir So I guess you can get to the airpor..."
# [Thread-11896] Requesting embedding for text: "@united we have tried to change our flight THREE t..."
# [Thread-548] Requesting embedding for text: "@AmericanAir flight 2470 tomorrow, have no idea if..."
# [Thread-2632] Requesting embedding for text: "@USAirways  I open the credit card and earn 44,000..."
# [Thread-17504] Requesting embedding for text: "@SouthwestAir I am committed okay please hook me u..."
# [Thread-15880] Requesting embedding for text: "@southwestair Landed an hour Late Flight from IND ..."
# [Thread-2204] Requesting embedding for text: "@AmericanAir delayed for two hours at ORD--&gt;CDG..."
# [Thread-21584] Requesting embedding for text: "@united @RobBogart After I waited hours in the air..."
# [Thread-16124] Requesting embedding for text: "@united yr team have me on hold for over an hour u..."
# [Thread-21604] Requesting embedding for text: "@AmericanAir @marxsterbcow How is this a real life..."
# [Thread-8584] Requesting embedding for text: "@united thank you for taking care of my mom and re..."
# [Thread-14684] Requesting embedding for text: "@JetBlue im still waiting??? No answer!!..."
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@JetBlue sitting on the plane in JFK waiting to ta..."
# Successfully got embedding for text ID 5539.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@SouthwestAir if I am a rapid awards member, does ..."
# Successfully got embedding for text ID 3844.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@united go to hell..."
# [Thread-2632] API call successful for text.
# Successfully got embedding for text ID 14271.
# [Thread-2632] Requesting embedding for text: "@USAirways you're the only airline that's not open..."
# Successfully got embedding for text ID 9173.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@USAirways yeah you guys just told me to call the ..."
# Successfully got embedding for text ID 1081.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@AmericanAir I need help Cancelled Flighting an up..."
# Successfully got embedding for text ID 11976.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@AmericanAir Last thing I want to deal w/ before 8..."
# Successfully got embedding for text ID 14211.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@AmericanAir I have a couple questions for you, if..."
# Successfully got embedding for text ID 3122.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@AmericanAir my flight 1337 is Cancelled Flightled..."
# Successfully got embedding for text ID 14554.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@JetBlue  Called JB 3 times!Everytime, Auto Vmsg:"..."
# Successfully got embedding for text ID 3039.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@JetBlue 2 hour delay while sitting on the plane a..."
# Successfully got embedding for text ID 2087.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@AmericanAir are you kidding me?  No one answering..."
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@AmericanAir awesome. Thanks!..."
# [Thread-16124] API call successful for text.
# Successfully got embedding for text ID 10703.
# [Thread-16124] Requesting embedding for text: "@united A day Late Flightr, one delayed &amp; one ..."
# Successfully got embedding for text ID 11244.
# Successfully got embedding for text ID 2232.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@united please don't take my membership away :(..."
# Successfully got embedding for text ID 5417.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@JetBlue thank you for the information...."
# Successfully got embedding for text ID 5450.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@united you realize you've said this already. At l..."
# Successfully got embedding for text ID 14219.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@USAirways this is so unacceptable. I'm going for ..."
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@USAirways 4 hours . How do I change my flight tha..."
# Successfully got embedding for text ID 6200.
# Successfully got embedding for text ID 8959.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@JetBlue are you going to be giving travel agent r..."
# Successfully got embedding for text ID 3909.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@USAirways always fun to get screwed out of an ear..."
# Successfully got embedding for text ID 7303.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@JetBlue really not acceptable. Just informed plan..."
# Successfully got embedding for text ID 2392.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@SouthwestAir I booked a flight on my phone and th..."
# Successfully got embedding for text ID 14387.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@USAirways Can someone please answer my call. I ha..."
# Successfully got embedding for text ID 11303.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@united reinstating the kosher meals that were dro..."
# Successfully got embedding for text ID 5011.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@VirginAmerica wifi AND better seating...."
# Successfully got embedding for text ID 11977.
# [Thread-8984] API call successful for text.
# [Thread-2204] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@AmericanAir I don't want to waste any more of my ..."
# [Thread-2204] Requesting embedding for text: "@JetBlue traveling w/ a rifle for a hunting trip, ..."
# [Thread-4180] API call successful for text.
# [Thread-11164] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@USAirways I’d suggest proper information dissemin..."
# [Thread-11164] Requesting embedding for text: "@AmericanAir followback..."
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@SouthwestAir love bridesmaid dancing Can't wait f..."
# Successfully got embedding for text ID 2337.
# Successfully got embedding for text ID 1992.
# Successfully got embedding for text ID 7882.
# Successfully got embedding for text ID 14376.
# Successfully got embedding for text ID 6759.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@AmericanAir appreciate update. Have also apprecia..."
# Successfully got embedding for text ID 7547.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@AmericanAir Lady at B1 ABQ for 5347 on 2/23 was o..."
# Successfully got embedding for text ID 9756.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@SouthwestAir guess where Ashley is. She's doing a..."
# Successfully got embedding for text ID 7195.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@USAirways I already did. My question is, why does..."
# Successfully got embedding for text ID 13166.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@united volumes, profit up http://t.co/pKfI9bTtzf ..."
# Successfully got embedding for text ID 13060.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@united can you help me with a delayed flight as i..."
# Successfully got embedding for text ID 13539.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@SouthwestAir just did, thank you..."
# Successfully got embedding for text ID 8449.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@USAirways Why is there no contact email for custo..."
# Successfully got embedding for text ID 9258.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@united still waiting..."
# Successfully got embedding for text ID 13269.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@JetBlue yes, today. Flight is full now. They said..."
# [Thread-21604] API call successful for text.
# Successfully got embedding for text ID 13123.
# [Thread-21604] Requesting embedding for text: "@SouthwestAir Working on a piece about military di..."
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@AmericanAir there is a full flight of customers s..."
# Successfully got embedding for text ID 11042.
# Successfully got embedding for text ID 3067.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@SouthwestAir is really gonna hear my mouth about ..."
# Successfully got embedding for text ID 3911.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@AmericanAir is the situation at JFK this evening ..."
# Successfully got embedding for text ID 14481.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@AmericanAir wasn't just a delay. Your counter wou..."
# Successfully got embedding for text ID 4038.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@SouthwestAir I appreciate the response, but the c..."
# [Thread-16124] API call successful for text.
# [Thread-16124] Requesting embedding for text: "@AmericanAir Cancelled Flightled my flight, didn't..."
# Successfully got embedding for text ID 12800.
# Successfully got embedding for text ID 1996.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@USAirways I didn't Cancelled Flight my flight, yo..."
# Successfully got embedding for text ID 13631.
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@usairways if you could change your name to @south..."
# [Thread-14684] API call successful for text.
# Successfully got embedding for text ID 10338.
# [Thread-19948] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@JetBlue Awesome! #bestairlineever..."
# [Thread-19948] Requesting embedding for text: "@united UA flight 1247. SFO to LAX took my carry o..."
# Successfully got embedding for text ID 8977.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@AmericanAir originating at SFO and going to LAX...."
# Successfully got embedding for text ID 10944.
# Successfully got embedding for text ID 8357.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@AmericanAir OMG ANSWER YOUR PHONE I HAVE BEEN ON ..."
# Successfully got embedding for text ID 4429.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@USAirways  And now your half assed plane is falli..."
# Successfully got embedding for text ID 2213.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@USAirways @AmericanAir 2hrs Late Flightr finally ..."
# Successfully got embedding for text ID 6595.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@JetBlue is definitely my new favorite airline...."
# Successfully got embedding for text ID 11829.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@SouthwestAir trying to rebook flight. On hold for..."
# Successfully got embedding for text ID 6140.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@united New Apple crâpe, amazing! Live from UA1207..."
# Successfully got embedding for text ID 5319.
# [Thread-23280] API call successful for text.
# [Thread-11164] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@AmericanAir yes but we HAVE TO GET HOME TOMORROW!..."
# [Thread-11164] Requesting embedding for text: "@USAirways was on hd for 1hr and 3min at 3:00am si..."
# Successfully got embedding for text ID 4658.
# [Thread-8984] API call successful for text.
# [Thread-16124] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@VirginAmerica @ChrysiChrysic your assistance yest..."
# [Thread-16124] Requesting embedding for text: "@United of urgency, but this is ridiculous. Your c..."
# [Thread-14684] API call successful for text.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@AmericanAir Are you people cruel or just stupid? ..."
# [Thread-14684] Requesting embedding for text: "@JetBlue could I get a free flight to Vegas since ..."
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@SouthwestAir Yes. Please train your customer serv..."
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@JetBlue Flight 69 (ha!) - one employee said they ..."
# Successfully got embedding for text ID 8807.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@VirginAmerica Will flights be leaving Dallas for ..."
# Successfully got embedding for text ID 11260.
# Successfully got embedding for text ID 14319.
# Successfully got embedding for text ID 477.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@united - well, now finally on board hopefully we ..."
# Successfully got embedding for text ID 7469.
# Successfully got embedding for text ID 6078.
# Successfully got embedding for text ID 11180.
# Successfully got embedding for text ID 1398.
# Successfully got embedding for text ID 10518.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@SouthwestAir Am I flying on Spirit air?..."
# Successfully got embedding for text ID 9833.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@USAirways can we hold two seats for 11:35 flight ..."
# Successfully got embedding for text ID 13496.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@united as for volunteers to give up seats, people..."
# Successfully got embedding for text ID 13947.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@USAirways a big thanks to the gate agent flt5127...."
# Successfully got embedding for text ID 14122.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@united @FAANews unacceptable practice to leave Ca..."
# Successfully got embedding for text ID 5334.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@JetBlue I waited 3 hrs for my bags and my flight ..."
# Successfully got embedding for text ID 5147.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@JetBlue Thanks! See you soon!..."
# Successfully got embedding for text ID 133.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@united on #UA3785 tonight and told delayed due to..."
# Successfully got embedding for text ID 1779.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@USAirways: I experienced what defines customer se..."
# Successfully got embedding for text ID 8436.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@USAirways Can you help with a seat assignment?  5..."
# Successfully got embedding for text ID 14223.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@united Thanks for the timely service &amp; great ..."
# Successfully got embedding for text ID 10222.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@VirginAmerica always!!! Xoxo..."
# Successfully got embedding for text ID 5915.
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: ".@USAirways thanks!..."
# Successfully got embedding for text ID 8311.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@USAirways US Airways website. So you double charg..."
# Successfully got embedding for text ID 14115.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@USAirways When you are deciding to wreck a vacati..."
# Successfully got embedding for text ID 12891.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "Just sent thank u RT @united: @goodenufmother Plea..."
# Successfully got embedding for text ID 11201.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@USAirways It's very difficult to work with Baggag..."
# Successfully got embedding for text ID 8766.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@USAirways thanks! Any idea when it will be resolv..."
# Successfully got embedding for text ID 12732.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@JetBlue Flight 1133 (N353JB) "Blue La La" departs..."
# Successfully got embedding for text ID 4312.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@USAirways No I was there 12 hrs early! Send me an..."
# Successfully got embedding for text ID 6022.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@AmericanAir - don't be jealous.  I live in Sydney..."
# Successfully got embedding for text ID 10603.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@usairways I have been on hold for over 3 hours.  ..."
# Successfully got embedding for text ID 1516.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@united if I wait I'll lose the flight. So frustra..."
# Successfully got embedding for text ID 54.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@VirginAmerica Flight Booking Problems flight to u..."
# Successfully got embedding for text ID 7462.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@united the long wait was the icing on the cake. W..."
# Successfully got embedding for text ID 7649.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@USAirways @landonschott he's fine, he really like..."
# Successfully got embedding for text ID 10708.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@USAirways I gave up http://t.co/2eDgc6TbLs..."
# Successfully got embedding for text ID 904.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@JetBlue I’m getting an “it depends” vibe. Fair en..."
# Successfully got embedding for text ID 9249.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@VirginAmerica LAX to EWR - Middle seat on a red e..."
# Successfully got embedding for text ID 9729.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@JetBlue is JFK still closed? Tryna get out of Ft ..."
# Successfully got embedding for text ID 138.[Thread-14684] API call successful for text.
#
# [Thread-14684] Requesting embedding for text: "@VirginAmerica Thanks for your great customer serv..."
# [Thread-16124] API call successful for text.
# [Thread-21604] API call successful for text.
# [Thread-16124] Requesting embedding for text: "@USAirways flt 5302 CLT to DAY supposed to depart ..."
# [Thread-21604] Requesting embedding for text: "@united says @USAirways  is the final carrier . Us..."
# Successfully got embedding for text ID 11408.
# Successfully got embedding for text ID 1076.
# Successfully got embedding for text ID 3062.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@AmericanAir Unfortunately that is not true. A rob..."
# Successfully got embedding for text ID 9963.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@SouthwestAir Finally got through after 3 hours an..."
# Successfully got embedding for text ID 2618.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@USAirways well I thought they had hours ago but j..."
# Successfully got embedding for text ID 12846.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@SouthwestAir @fly2midway 45 minute wait for my ba..."
# Successfully got embedding for text ID 8830.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@united more people stranded cause you suck. Bette..."
# Successfully got embedding for text ID 1932.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@AmericanAir crew did the best they could but it w..."
# Successfully got embedding for text ID 9082.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@SouthwestAir any chance they will change this to ..."
# Successfully got embedding for text ID 9172.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@United now what?!? http://t.co/5hpSqVRjK8 flight ..."
# [Thread-21604] API call successful for text.
# [Thread-16124] API call successful for text.
# [Thread-548] API call successful for text.
# [Thread-16124] Requesting embedding for text: ".@USAirways Have you just given up?..."
# [Thread-548] Requesting embedding for text: "@AmericanAir spent hour+ trying to check after to ..."
# [Thread-21604] Requesting embedding for text: "“@JetBlue: Our fleet's on fleek. http://t.co/PULp4..."
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@USAirways sitting on the Tarmac waiting to deplan..."
# Successfully got embedding for text ID 246.
# Successfully got embedding for text ID 11674.
# Successfully got embedding for text ID 9658.
# Successfully got embedding for text ID 2287.
# Successfully got embedding for text ID 9486.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@USAirways Flight 2069 from JFK to Charlotte, then..."
# Successfully got embedding for text ID 29.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@AmericanAir btr trained gate agts. Im a frequent ..."
# Successfully got embedding for text ID 8641.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@united nice. I wonder how you pick who to respond..."
# Successfully got embedding for text ID 9217.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@AmericanAir We all did! Skipper's walk-around too..."
# Successfully got embedding for text ID 4826.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@USAirways got through on the phone. usair Cancell..."
# Successfully got embedding for text ID 343.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@united I need help with a missing bag...."
# Successfully got embedding for text ID 4169.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@JetBlue #kudos! And we're done and heading to war..."
# Successfully got embedding for text ID 13999.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@USAirways so you're going to make me wait that lo..."
# Successfully got embedding for text ID 12830.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@united yes I have &amp; they're unsure when it wo..."
# Successfully got embedding for text ID 11557.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@united thanks for having ground crews that are su..."
# Successfully got embedding for text ID 7604.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@SouthwestAir there really should not be guidance ..."
# Successfully got embedding for text ID 2791.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@SouthwestAir the flight isn't that empty.... Is t..."
# Successfully got embedding for text ID 11017.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@AmericanAir THANK YOU FOR ALL THE HELP!  :P You g..."
# Successfully got embedding for text ID 13546.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@USAirways horrible experience to key west lost lu..."
# Successfully got embedding for text ID 6397.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@united why do you want me to be loyal  if don't l..."
# Successfully got embedding for text ID 1561.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@united thanks for having no one to pilot my last ..."
# Successfully got embedding for text ID 11267.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@SouthwestAir is having a sale! I'm delighted!..."
# Successfully got embedding for text ID 12794.
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@USAirways @AmericanAir Not providing pilots for y..."
# Successfully got embedding for text ID 11426.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@JetBlue I did not report the updated info - don't..."
# Successfully got embedding for text ID 910.
# [Thread-21584] API call successful for text.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@VirginAmerica Random Q: what's the distribution o..."
# [Thread-21584] Requesting embedding for text: "@USAirways worst customer service. ticket was 180 ..."
# Successfully got embedding for text ID 11525.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@AmericanAir These are some awesome photos. Thanks..."
# Successfully got embedding for text ID 12490.
# Successfully got embedding for text ID 7795.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@SouthwestAir Scott is the best!!! Thank yo from t..."
# Successfully got embedding for text ID 2054.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@USAirways Three hour delay from Miami to London. ..."
# Successfully got embedding for text ID 1665.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@SouthwestAir can you please DM me who I can speak..."
# Successfully got embedding for text ID 5567.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@united flight from san fransico to jfk was evacua..."
# Successfully got embedding for text ID 2091.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@AmericanAir Filed a PIR with an agent at Indianap..."
# Successfully got embedding for text ID 11831.
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@JetBlue Ok. Thanks for your help...."
# Successfully got embedding for text ID 9779.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@AmericanAir most disgusting chicken entree I've e..."
# Successfully got embedding for text ID 11997.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@JetBlue Looking cool..."
# Successfully got embedding for text ID 87.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@united either your staff or whoever you contract ..."
# Successfully got embedding for text ID 7151.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@JetBlue A320 pulling into the gate as the sunrise..."
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@united Just did, thanks for checking! :)..."
# Successfully got embedding for text ID 2856.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@AmericanAir Can you respond to my DM?..."
# Successfully got embedding for text ID 5934.
# Successfully got embedding for text ID 10868.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@SouthwestAir Thanks for taking care of me Today! ..."
# Successfully got embedding for text ID 6656.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@USAirways Your policy needs a serious revision fo..."
# Successfully got embedding for text ID 13138.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "Why “@JetBlue: Our fleet's on fleek. http://t.co/a..."
# Successfully got embedding for text ID 6630.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@united what time should I arrive at the airport f..."
# Successfully got embedding for text ID 8522.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@united I sent you a DM as requested but have not ..."
# Successfully got embedding for text ID 5216.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@united assistance with what, the attitude of your..."
# Successfully got embedding for text ID 1693.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@united so unhelpful... http://t.co/vBfIeo2qJC..."
# Successfully got embedding for text ID 4488.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@SouthwestAir was on flight 2373 from CHI-BUF last..."
# Successfully got embedding for text ID 10822.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@SouthwestAir the woman working the counter in phi..."
# Successfully got embedding for text ID 1397.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@united Would be nice if @staralliance partner tic..."
# Successfully got embedding for text ID 10065.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@JetBlue and they are telling me I got to get anot..."
# Successfully got embedding for text ID 1756.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@united I miss the Continental days...."
# Successfully got embedding for text ID 6823.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@united http://t.co/hj5kq82Chn, however, is comple..."
# Successfully got embedding for text ID 12931.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@united @jsumiyasu I am thankful to the  United gr..."
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@JetBlue 's free wifi on board is the best thing t..."
# Successfully got embedding for text ID 6461.
# Successfully got embedding for text ID 1728.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@AmericanAir no gate agent after 30 minutes to let..."
# Successfully got embedding for text ID 7040.
# [Thread-16124] API call successful for text.
# [Thread-16124] Requesting embedding for text: "@JetBlue Phew!! Did it!! (Pant. Wheeze) http://t.c..."
# Successfully got embedding for text ID 9301.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@JetBlue I left my apt 10hrs ago to go from Boston..."
# Successfully got embedding for text ID 13613.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@SouthwestAir how long does it take for my Rapid R..."
# Successfully got embedding for text ID 2655.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@united Follow me back, please, and I'll happily D..."
# Successfully got embedding for text ID 13439.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@SouthwestAir Airline trouble &amp; not getting sa..."
# [Thread-21584] API call successful for text.
# Successfully got embedding for text ID 6607.
# [Thread-21584] Requesting embedding for text: "@JetBlue no excuse though for 3 gate changes thoug..."
# Successfully got embedding for text ID 4406.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@JetBlue @Amagrino will you cover the cost of my c..."
# Successfully got embedding for text ID 1441.
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@JetBlue @martysg you *know* how I love you, JB, b..."
# Successfully got embedding for text ID 7304.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@united how much longer will it take? It a guitar,..."
# Successfully got embedding for text ID 1884.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@SouthwestAir I never got my flight confirmation. ..."
# Successfully got embedding for text ID 9093.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@SouthwestAir "Will my luggage be on that flight?"..."
# Successfully got embedding for text ID 8927.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@AmericanAir there are no more flights via united ..."
# Successfully got embedding for text ID 7168.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@SouthwestAir just got a call apologizing personal..."
# Successfully got embedding for text ID 855.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@USAirways Darn it, first in line for no upgrade! ..."
# Successfully got embedding for text ID 2608.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@united wanted to, but you Cancelled Flightled my ..."
# Successfully got embedding for text ID 2659.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@united Thanks to Karen Salisbury at IAH for amazi..."
# Successfully got embedding for text ID 5067.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@united I appreciate the follow up...."
# Successfully got embedding for text ID 4442.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@JetBlue flight 1025 JFK to TPA 8:05am on Saturday..."
# Successfully got embedding for text ID 13903.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@USAirways please fix the very unproductive check ..."
# Successfully got embedding for text ID 8629.
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@USAirways who would like to watch the video of ho..."
# Successfully got embedding for text ID 7230.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@SouthwestAir Thanks! I know the routes you curren..."
# Successfully got embedding for text ID 5295.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "“@USAirways: @jdbwaffles We're excited to have you..."
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@SouthwestAir you know I ❤️you but trying my patie..."
# Successfully got embedding for text ID 12601.
# Successfully got embedding for text ID 3730.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@SouthwestAir I am trying to book another flight a..."
# Successfully got embedding for text ID 8189.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@USAirways found great prices thru US Air for hone..."
# Successfully got embedding for text ID 1645.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@united @TiffanyAndCo @NTrustOpen ah, so that's wh..."
# Successfully got embedding for text ID 4845.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@AmericanAir tell me you can get me to ABI earlier..."
# Successfully got embedding for text ID 4656.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@JetBlue why are you always so amazing! #jetblue #..."
# Successfully got embedding for text ID 4286.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@united installed and working are not the same. Ki..."
# Successfully got embedding for text ID 2643.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@AmericanAir I certainly hope my LA /PBI on 25 th ..."
# Successfully got embedding for text ID 7527.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@VirginAmerica is saving my sanity right now: http..."
# Successfully got embedding for text ID 9584.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@USAirways status shows "delayed" it was just "wai..."
# Successfully got embedding for text ID 10984.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@USAirways @nanceebing 4 hour hold times at the mo..."
# Successfully got embedding for text ID 5684.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@USAirways your app is bad, and you should feel ba..."
# Successfully got embedding for text ID 780.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@JetBlue, your hold music sucks...."
# Successfully got embedding for text ID 4287.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@AmericanAir How best to talk with an agent to res..."
# Successfully got embedding for text ID 5796.
# [Thread-16124] API call successful for text.
# [Thread-16124] Requesting embedding for text: "@united How do I get through @TSA to finally board..."
# Successfully got embedding for text ID 7792.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@united done..."
# Successfully got embedding for text ID 6848.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@united Hi again, any updates here?..."
# Successfully got embedding for text ID 6160.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@united compensate us for new clothes bet you won'..."
# Successfully got embedding for text ID 12606.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@AmericanAir - And @AirSouthwest  had a flight fro..."
# Successfully got embedding for text ID 4100.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@united "where we trick you into making us look po..."
# Successfully got embedding for text ID 11780.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@united 100. % failure in 2015 #UnitedAirlines..."
# Successfully got embedding for text ID 11199.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@SouthwestAir How do I enter passport information ..."
# Successfully got embedding for text ID 13642.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@AmericanAir when the pilot announces that the pla..."
# Successfully got embedding for text ID 10473.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@AmericanAir are flights from Columbus Ohio to Dal..."
# Successfully got embedding for text ID 7520.
# [Thread-17588] API call successful for text.
# [Thread-17588] Requesting embedding for text: "@united I guess. But what is the excuse for unders..."
# Successfully got embedding for text ID 11123.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@VirginAmerica This is such a great deal! Already ..."
# Successfully got embedding for text ID 2985.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@united I already sent feedback and your reps are ..."
# Successfully got embedding for text ID 1451.
# [Thread-16124] API call successful for text.
# [Thread-16124] Requesting embedding for text: "@united thanks. Just was able to do it on the app ..."
# Successfully got embedding for text ID 1433.
# [Thread-8584] API call successful for text.
# [Thread-8584] Requesting embedding for text: "@VirginAmerica you know it. Need it on my spotify ..."
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@SouthwestAir Redeem-points packages magically gon..."
# Successfully got embedding for text ID 7402.
# [Thread-14684] API call successful for text.
# [Thread-14684] Requesting embedding for text: "@AmericanAir 245. I'm about to take off but one of..."
# Successfully got embedding for text ID 10166.
# Successfully got embedding for text ID 1829.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@SouthwestAir flights from sunny SFO delayed for h..."
# Successfully got embedding for text ID 1612.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@united can you send me another confirmation email..."
# Successfully got embedding for text ID 4190.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@USAirways yesterday we were delayed for SIX hours..."
# Successfully got embedding for text ID 13345.
# [Thread-17504] API call successful for text.
# [Thread-17504] Requesting embedding for text: "@AmericanAir thanks for forcing me to check -in my..."
# Successfully got embedding for text ID 10785.
# [Thread-8984] API call successful for text.
# [Thread-8984] Requesting embedding for text: "@USAirways understood and I am sympathetic. How do..."
# Successfully got embedding for text ID 3326.
# [Thread-23280] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@JetBlue before departure, while people who are de..."
# Successfully got embedding for text ID 13630.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@SouthwestAir please expedite missing bag claim #3..."
# Successfully got embedding for text ID 7517.
# [Thread-12124] API call successful for text.
# [Thread-12124] Requesting embedding for text: "@united Definitely a compliment! I really thought ..."
# Successfully got embedding for text ID 3456.
# [Thread-21584] API call successful for text.
# [Thread-21584] Requesting embedding for text: "@AmericanAir LAX-OGG-LAX using hard earned miles a..."
# Successfully got embedding for text ID 14502.
# [Thread-16124] API call successful for text.
# [Thread-16124] Requesting embedding for text: "@SouthwestAir #RedCarpet Southwest Companion Pass ..."
# Successfully got embedding for text ID 1726.
# [Thread-548] API call successful for text.
# [Thread-548] Requesting embedding for text: "@VirginAmerica is anyone doing anything there toda..."
# Successfully got embedding for text ID 4401.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@JetBlue thank you!!..."
# Successfully got embedding for text ID 877.
# [Thread-14768] API call successful for text.
# [Thread-14768] Requesting embedding for text: "@JetBlue you guys rock!! http://t.co/LA397zaoAY..."
# Successfully got embedding for text ID 3807.
# [Thread-15880] API call successful for text.
# [Thread-15880] Requesting embedding for text: "@AmericanAir The delay is nothing but the personne..."
# Successfully got embedding for text ID 9965.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@AmericanAir SFO. Natt (the agent who helped me) r..."
# Successfully got embedding for text ID 12349.
# [Thread-21604] API call successful for text.
# [Thread-21604] Requesting embedding for text: "@SouthwestAir Thanks! Confirmation number just DMe..."
# Successfully got embedding for text ID 5843.
# [Thread-15736] API call successful for text.
# [Thread-15736] Requesting embedding for text: "@jetblue Vegas desk said JFK connect would b held ..."
# Successfully got embedding for text ID 5638.
# [Thread-4180] API call successful for text.
# [Thread-4180] Requesting embedding for text: "@SouthwestAir Traveling with a 13 year old Thursda..."
# Successfully got embedding for text ID 12.
# [Thread-19948] API call successful for text.
# [Thread-19948] Requesting embedding for text: "@AmericanAir I can't keep dialing you guys all day..."
# Successfully got embedding for text ID 4177.
# [Thread-23280] API call successful for text.
# [Thread-17588] API call successful for text.
# [Thread-23280] Requesting embedding for text: "@SouthwestAir prove it, Cuz the southwest people h..."
# [Thread-17588] Requesting embedding for text: "@united or frontier ... http://t.co/n8WiNFu6C5..."
# Successfully got embedding for text ID 8022.
# Successfully got embedding for text ID 1173.
# [Thread-2632] API call successful for text.
# [Thread-2632] Requesting embedding for text: "@AmericanAir @cjdjpdx not a valid response in 2015..."
# Successfully got embedding for text ID 309.
# [Thread-11164] API call successful for text.
# [Thread-11164] Requesting embedding for text: "@USAirways Have a 6:05pm flight out of PHL Sat, 2/..."
# Successfully got embedding for text ID 6211.
# [Thread-11896] API call successful for text.
# [Thread-11896] Requesting embedding for text: "@USAirways I have better Intel than she does!  She..."
# Successfully got embedding for text ID 7219.
# [Thread-2204] API call successful for text.
# [Thread-2204] Requesting embedding for text: "@USAirways stuck on the runway for 2 hrs 10 min du..."
# ...
# Successfully got embedding for text ID 2524.
# [Thread-10740] API call successful for text.
# [Thread-10740] Requesting embedding for text: "@JetBlue Thank you...."
# Successfully got embedding for text ID 4354.
# [Thread-8440] API call successful for text.
# [Thread-8440] Requesting embedding for text: "Keep Waiting, time does not cost anything for @Jet..."
# Successfully got embedding for text ID 4811.
# [Thread-15376] API call successful for text.
# [Thread-15376] Requesting embedding for text: "@united, if you mean beyond opaque "maintenance is..."
# Successfully got embedding for text ID 9357.
# [Thread-15952] API call successful for text.
# [Thread-15952] Requesting embedding for text: "@united crew has been notified, passenger moved bu..."
# Successfully got embedding for text ID 6940.
# [Thread-21132] API call successful for text.
# [Thread-21132] Requesting embedding for text: "@VirginAmerica I tried that. You offered to charge..."
# Successfully got embedding for text ID 7349.
# [Thread-9272] API call successful for text.[Thread-2400] API call successful for text.
# [Thread-2400] Requesting embedding for text: "@USAirways customer service fail... Todays experie..."
#
# Successfully got embedding for text ID 4899.
# [Thread-16540] API call successful for text.
# [Thread-9272] Requesting embedding for text: "@JetBlue, I normally ❤️ you, but this Late Flights..."
# [Thread-16540] Requesting embedding for text: "@USAirways is moving the plane to the end of the r..."
# Successfully got embedding for text ID 12221.
# Successfully got embedding for text ID 3008.
# [Thread-19444] API call successful for text.
# [Thread-19444] Requesting embedding for text: "@SouthwestAir BTW I was completely unable to buy w..."
# Successfully got embedding for text ID 1348.
# [Thread-19008] API call successful for text.
# [Thread-19008] Requesting embedding for text: "@USAirways If I am traveling with an infant in my ..."
# Successfully got embedding for text ID 7276.
# [Thread-8496] API call successful for text.
# [Thread-8496] Requesting embedding for text: "@AmericanAir When I left Orlando, I was 2nd in lin..."
# Successfully got embedding for text ID 14485.
# [Thread-2416] API call successful for text.
# [Thread-2416] Requesting embedding for text: "@JetBlue if I tell you I like that @warriors pick,..."
# Successfully got embedding for text ID 5728.
# [Thread-2824] API call successful for text.
# [Thread-2824] Requesting embedding for text: "@AmericanAir that is absolutely false stmt.  You h..."
# [Thread-7516] API call successful for text.
# [Thread-7516] Requesting embedding for text: "@united Missing crew, passenger doc problems, froz..."
# Successfully got embedding for text ID 4379.
# Successfully got embedding for text ID 11710.
# [Thread-20980] API call successful for text.
# [Thread-20980] Requesting embedding for text: "@SouthwestAir due to an apparent water issue that ..."
# Successfully got embedding for text ID 2994.
# [Thread-6368] API call successful for text.
# [Thread-6368] Requesting embedding for text: "@united why is my flight from mke to ord getting d..."
# Successfully got embedding for text ID 11996.
# [Thread-10740] API call successful for text.
# [Thread-988] API call successful for text.
# [Thread-10740] Requesting embedding for text: "@USAirways our flight was rebooked with you and we..."
# [Thread-16552] API call successful for text.
# [Thread-16552] Requesting embedding for text: ".@JetBlue Navigating through 2 rebooks due to flu ..."
# [Thread-15376] API call successful for text.
# Successfully got embedding for text ID 7982.
# [Thread-988] Requesting embedding for text: "@JetBlue you guys continue to impress. Your crew @..."
# [Thread-15376] Requesting embedding for text: "@united #bullying in the #workforce not ok. Get ga..."
# Successfully got embedding for text ID 11440.
# Successfully got embedding for text ID 12062.
# Successfully got embedding for text ID 2723.
# [Thread-14268] API call successful for text.
# [Thread-14268] Requesting embedding for text: "@united it's highly unprofessional for you to over..."
# Successfully got embedding for text ID 2446.
# [Thread-15952] API call successful for text.
# [Thread-15952] Requesting embedding for text: "@USAirways @traveloneworld .. Utterly frustrated a..."
# Successfully got embedding for text ID 2977.
# [Thread-21132] API call successful for text.
# [Thread-21132] Requesting embedding for text: "@united @highbuddyyy that totally sucks my cousin ..."
# Successfully got embedding for text ID 444.
# [Thread-2400] API call successful for text.
# [Thread-2400] Requesting embedding for text: "@AmericanAir of course it wasn't your intention, i..."
# Successfully got embedding for text ID 9968.
# [Thread-9272] API call successful for text.
# [Thread-9272] Requesting embedding for text: "@united It is also inappropriate to lie to passeng..."
# Successfully got embedding for text ID 8900.
# [Thread-19436] API call successful for text.
# [Thread-19436] Requesting embedding for text: "@USAirways that's incorrect. Four people, last fli..."
# Successfully got embedding for text ID 10156.
# [Thread-19444] API call successful for text.
# [Thread-19444] Requesting embedding for text: "@united bags are still in Houston since Friday and..."
# [Thread-19008] API call successful for text.
# [Thread-19008] Requesting embedding for text: "@united I am very glad I took care of own reschedu..."
# Successfully got embedding for text ID 4970.
# Successfully got embedding for text ID 10469.
# [Thread-8496] API call successful for text.
# [Thread-8496] Requesting embedding for text: "@AmericanAir shoutout to the agent on duty now @ G..."
# Successfully got embedding for text ID 14572.
# [Thread-2416] API call successful for text.
# [Thread-2416] Requesting embedding for text: "@united seriously #fail on making strangers share ..."
# Successfully got embedding for text ID 8498.
# [Thread-16540] API call successful for text.
# [Thread-16540] Requesting embedding for text: "@united BUT you have received confirmation via ema..."
# Successfully got embedding for text ID 10945.
# [Thread-7516] API call successful for text.
# [Thread-7516] Requesting embedding for text: "@SouthwestAir  you are over 40, please start actin..."
# [Thread-2824] API call successful for text.
# Successfully got embedding for text ID 3736.
# [Thread-2824] Requesting embedding for text: "@JetBlue We had some major plane-wide DirectTV iss..."
# Successfully got embedding for text ID 13535.
# [Thread-8440] API call successful for text.
# [Thread-8440] Requesting embedding for text: "@JetBlue this feels nice - what we've got going on..."
# Successfully got embedding for text ID 7309.
# [Thread-15376] API call successful for text.
# [Thread-15376] Requesting embedding for text: "@JetBlue pls send an IT tech 2 baggage office. Poo..."
# Successfully got embedding for text ID 2452.
# [Thread-988] API call successful for text.
# [Thread-988] Requesting embedding for text: "@united exactly it states a secure document is a n..."
# Successfully got embedding for text ID 8646.
# [Thread-10740] API call successful for text.
# [Thread-10740] Requesting embedding for text: "@USAirways some people in line have been waiting 5..."
# Successfully got embedding for text ID 9388.
# [Thread-14268] API call successful for text.
# [Thread-14268] Requesting embedding for text: "@SouthwestAir Is the 1,750 bonus at 1800Flowers st..."
# Successfully got embedding for text ID 797.
# [Thread-15952] API call successful for text.
# [Thread-15952] Requesting embedding for text: "@SouthwestAir thank you. See u next wednesday in F..."
# Successfully got embedding for text ID 10328.
# [Thread-2400] API call successful for text.
# [Thread-2400] Requesting embedding for text: "@JetBlue time to reevaluate my nyc carrier...."
# Successfully got embedding for text ID 14170.
# [Thread-21132] API call successful for text.
# [Thread-21132] Requesting embedding for text: "@USAirways we flew out, through and into good weat..."
# Successfully got embedding for text ID 526.
# [Thread-6368] API call successful for text.
# [Thread-6368] Requesting embedding for text: "@VirginAmerica awesome. I flew yall Sat morning. A..."
# Successfully got embedding for text ID 3783.
# [Thread-9272] API call successful for text.
# [Thread-9272] Requesting embedding for text: "@united Brothers luggage was lost on Copa Airlines..."
# Successfully got embedding for text ID 1907.
# [Thread-19008] API call successful for text.
# [Thread-19008] Requesting embedding for text: "@united traveling with @MegZezzo who is injured. G..."
# Successfully got embedding for text ID 1377.
# [Thread-16552] API call successful for text.
# [Thread-16552] Requesting embedding for text: "@JetBlue  I'm game if you're buying!!  ;)..."
# Successfully got embedding for text ID 6907.
# [Thread-7516] API call successful for text.
# [Thread-7516] Requesting embedding for text: "@JetBlue, was far less painful than what was comin..."
# Successfully got embedding for text ID 6414.
# [Thread-19444] API call successful for text.
# [Thread-19444] Requesting embedding for text: "@SouthwestAir I was on hold for over 2 hours and m..."
# Successfully got embedding for text ID 4217.
# [Thread-19436] API call successful for text.
# [Thread-19436] Requesting embedding for text: "@united can you not get the first flight of the da..."
# Successfully got embedding for text ID 10989.
# [Thread-988] API call successful for text.
# [Thread-988] Requesting embedding for text: "@USAirways @AmericanAir won't even refund for a fl..."
# Successfully got embedding for text ID 4068.
# [Thread-14268] API call successful for text.
# [Thread-14268] Requesting embedding for text: "@SouthwestAir breaking my heart at BWI 9 hrs @busi..."
# Successfully got embedding for text ID 6202.
# [Thread-15952] API call successful for text.
# [Thread-15952] Requesting embedding for text: "@united we were not given the option of using our ..."
# Successfully got embedding for text ID 5521.
# [Thread-2400] API call successful for text.
# [Thread-2400] Requesting embedding for text: "@united Why announce it is for rollers at all? If ..."
# Successfully got embedding for text ID 8207.
# [Thread-2824] API call successful for text.
# [Thread-2824] Requesting embedding for text: "@USAirways the call hung up on me....."
# [Thread-21132] API call successful for text.
# [Thread-21132] Requesting embedding for text: ".@AmericanAir Advised GAs and pilot of my flight. ..."
# Successfully got embedding for text ID 7000.
# [Thread-6368] API call successful for text.
# [Thread-6368] Requesting embedding for text: "@SouthwestAir Thanks! Sent a DM to you. Let me kno..."
# Successfully got embedding for text ID 9701.
# Successfully got embedding for text ID 75.
# [Thread-19008] API call successful for text.
# [Thread-19008] Requesting embedding for text: "@united I live abroad and am Flight Booking Proble..."
# Successfully got embedding for text ID 1191.
# [Thread-15376] API call successful for text.
# [Thread-15376] Requesting embedding for text: "@AmericanAir hats off to Admiral Lounge attendant ..."
# [Thread-10740] API call successful for text.
# Successfully got embedding for text ID 8828.
# [Thread-16552] API call successful for text.
# [Thread-10740] Requesting embedding for text: "@united 4 people MCI to DEL. Preferably with Jet A..."
# [Thread-16552] Requesting embedding for text: "@JetBlue Awesome, thanks! I'll give a call Late Fl..."
# Successfully got embedding for text ID 11148.
# Successfully got embedding for text ID 8621.
# [Thread-2416] API call successful for text.
# [Thread-2416] Requesting embedding for text: "@USAirways why would a flight arrive Late Flight o..."
# Successfully got embedding for text ID 783.
# [Thread-8496] API call successful for text.
# [Thread-8496] Requesting embedding for text: "@united First complaint filed on Feb 11th, over 10..."
# Successfully got embedding for text ID 14261.
# [Thread-16540] API call successful for text.
# [Thread-16540] Requesting embedding for text: "@USAirways US 728 pilot started the flight by anno..."
# Successfully got embedding for text ID 1155.
# [Thread-7516] API call successful for text.
# [Thread-7516] Requesting embedding for text: "Only 14 biz days (18 calendar) to respond to my in..."
# Successfully got embedding for text ID 8192.
# [Thread-19444] API call successful for text.
# [Thread-19444] Requesting embedding for text: "@JetBlue got it wish they would communicate more w..."
# Successfully got embedding for text ID 5087.
# [Thread-14268] API call successful for text.
# [Thread-14268] Requesting embedding for text: "@united THRILLED to have my carry-on checked again..."
# Successfully got embedding for text ID 5181.
# [Thread-19436] API call successful for text.
# [Thread-19436] Requesting embedding for text: ".@SouthwestAir I appreciate that, and not to be ru..."
# Successfully got embedding for text ID 1997.
# [Thread-988] API call successful for text.
# [Thread-988] Requesting embedding for text: "@united i DMed you the details..."
# Successfully got embedding for text ID 10456.
# [Thread-15952] API call successful for text.
# [Thread-15952] Requesting embedding for text: "@AmericanAir The flight was delayed 5 times. Spent..."
# Successfully got embedding for text ID 664.
# [Thread-21132] API call successful for text.
# [Thread-21132] Requesting embedding for text: "@USAirways sad experience today on 4663.  Family o..."
# Successfully got embedding for text ID 12747.
# [Thread-19008] API call successful for text.
# [Thread-19008] Requesting embedding for text: "@USAirways Seriously. You can't tweet and let peop..."
# Successfully got embedding for text ID 3508.
# [Thread-16552] API call successful for text.[Thread-15376] API call successful for text.
#
# [Thread-15376] Requesting embedding for text: "@AmericanAir I saw it finally come through on the ..."
# Successfully got embedding for text ID 13973.
# [Thread-16552] Requesting embedding for text: "@USAirways Many thanks for your reply! http://t.co..."
# [Thread-20980] API call successful for text.
# Successfully got embedding for text ID 8356.
# Successfully got embedding for text ID 4414.
# [Thread-10740] API call successful for text.
# Successfully got embedding for text ID 1206.
# [Thread-8440] API call successful for text.
# [Thread-2416] API call successful for text.
# Successfully got embedding for text ID 8576.
# Successfully got embedding for text ID 11468.
# [Thread-8496] API call successful for text.
# Successfully got embedding for text ID 1345.
# [Thread-9272] API call successful for text.
# Successfully got embedding for text ID 2590.
# [Thread-16540] API call successful for text.
# Successfully got embedding for text ID 9417.
# [Thread-2400] API call successful for text.
# Successfully got embedding for text ID 1410.
# [Thread-2824] API call successful for text.
# Successfully got embedding for text ID 9664.
# [Thread-19436] API call successful for text.
# Successfully got embedding for text ID 6406.
# [Thread-19444] API call successful for text.
# Successfully got embedding for text ID 7805.
# [Thread-14268] API call successful for text.
# Successfully got embedding for text ID 4305.
# [Thread-15952] API call successful for text.
# Successfully got embedding for text ID 12244.
# [Thread-19008] API call successful for text.
# Successfully got embedding for text ID 10282.
# [Thread-16552] API call successful for text.
# Successfully got embedding for text ID 10204.
# [Thread-21132] API call successful for text.
# Successfully got embedding for text ID 10218.
# [Thread-15376] API call successful for text.[Thread-6368] API call successful for text.
#
# Successfully got embedding for text ID 13358.
# Successfully got embedding for text ID 4437.
# [Thread-988] API call successful for text.
# Successfully got embedding for text ID 549.
# [Thread-7516] API call successful for text.
# Successfully got embedding for text ID 1809.
# Embedding generation finished.
# Summary: {'processed_successfully': 2196, 'failed_embedding_or_processing': 0, 'skipped_invalid_text': 0, 'output_path': '../../data/hyperparamter_tuning_llm_embedding_test.csv.gz', 'total_texts_in_series': 2196}
# {'processed_successfully': 2196, 'failed_embedding_or_processing': 0, 'skipped_invalid_text': 0, 'output_path': '../../data/hyperparamter_tuning_llm_embedding_test.csv.gz', 'total_texts_in_series': 2196}

# %%
import numpy
import json

train_vectorized = pd.read_csv("../../data/hyperparameter_tuning_llm_embedding_train.csv.gz", compression="gzip")
valid_vectorized = pd.read_csv("../../data/hyperparamter_tuning_llm_embedding_valid.csv.gz", compression="gzip")
test_vectorized = pd.read_csv("../../data/hyperparamter_tuning_llm_embedding_test.csv.gz", compression="gzip")

X_train_vectorized = train_vectorized["embedding_json"].apply(json.loads) # convert string into a list of 765 items in 1 column
X_train_vectorized = numpy.vstack(X_train_vectorized) # turn that list of 765 items into 765 features / columns
y_train = train_vectorized["encoded_sentiment"]

X_valid_vectorized = valid_vectorized["embedding_json"].apply(json.loads)
X_valid_vectorized = numpy.vstack(X_valid_vectorized)

X_test_vectorized = test_vectorized["embedding_json"].apply(json.loads)
X_test_vectorized = numpy.vstack(X_test_vectorized)

y_valid = valid_vectorized["encoded_sentiment"]
y_test = test_vectorized["encoded_sentiment"]

# %%
# ---- 3. Handling class imbalance issue with SMOTE --- 
from imblearn.over_sampling import SMOTE

# Handling imbalanced using SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_vectorized, y_train)

# %%
# --- 4. Hyperparameter Tuning with RandomizedSearchCV ---
print("\nStarting Hyperparameter Tuning...")

import joblib
# Define the XGBoost classifier.
# We set a random_state for reproducibility of the model's internal processes.
# The 'objective' is set to 'multi:softprob' for multi-class classification.
# We also set 'use_label_encoder=False' to avoid a deprecation warning.

# Initialize the XGBoost Classifier
model_path = "../../models/best_model_llm_embedding.pkl"
if os.path.exists(model_path):
    print("Loading existing model...")
    best_model = joblib.load(model_path)

else:
    xgb_clf = XGBClassifier(
        objective='multi:softprob',
        use_label_encoder=False,
        eval_metric='mlogloss',
        random_state=42 # Set random_state for reproducibility
    )

    xgb_clf = XGBClassifier(max_depth=10,
                                random_state=42,
                                # Introduce randomness to make training faster and reduce overfitting
                                subsample=0.8, ## Uses 80% of the data for each tree.
                                colsample_bytree=0.8, ## Uses 80% of the features for each tree.
                                # the parameters below make the model trained faster by enabling parallelism
                                n_jobs = -1)

    # Define the parameter grid to search.
    param_grid = {
        'max_depth': [3, 4, 5],
        'learning_rate': [0.01, 0.1, 0.2],
        'n_estimators': [100, 200],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0]
    }

    # Set up RandomizedSearchCV to find the best parameters.
    # cv=3 specifies 3-fold cross-validation.
    # n_jobs=-1 will use all available CPU cores to speed up the process.
    # verbose=2 will print progress updates.
    # Note: The cross-validation splitting in RandomizedSearchCV is also a random process.
    # By default, it uses StratifiedKFold for classifiers, which has a shuffle=True default.
    # While not strictly necessary if train_test_split is seeded, it's good practice to also control this.
    from sklearn.model_selection import StratifiedKFold
    cv_strategy = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    grid_search = RandomizedSearchCV(
        estimator=xgb_clf,
        param_distributions=param_grid,
        scoring='accuracy',
        cv=cv_strategy, # Use the defined cross-validation strategy
        verbose=2,
        n_jobs=-1
    )

    # Fit RandomizedSearchCV to the training data. This will train and evaluate the model with random parameter combinations.
    grid_search.fit(X_train_resampled, y_train_resampled)
    
    joblib.dump(grid_search, model_path)
# Out:
# Starting Hyperparameter Tuning...
# Loading existing model...

# %%
# --- 5. Evaluate the Best Model ---
print("\nHyperparameter tuning complete.")
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best cross-validation accuracy: {grid_search.best_score_:.4f}")

# Get the best model found by RandomizedSearchCV
best_model = grid_search.best_estimator_
# Out:
# Hyperparameter tuning complete.
# Best parameters found: {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.2, 'colsample_bytree': 0.8}
# Best cross-validation accuracy: 0.9342

# %%
# --- 5. Evaluate the Best Model ---
print("\nHyperparameter tuning complete.")
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best cross-validation accuracy: {grid_search.best_score_:.4f}")

# Get the best model found by RandomizedSearchCV
best_model = grid_search.best_estimator_
# Out:
# Hyperparameter tuning complete.
# Best parameters found: {'subsample': 0.8, 'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.2, 'colsample_bytree': 0.8}
# Best cross-validation accuracy: 0.9342

# %%
# Make predictions on the test set
# For 'multi:softprob', predict_proba() gives probabilities for each class.
# We use np.argmax to get the class with the highest probability.

### (A) Evaluate the model's performance for Valid set
y_valid_proba_pred = best_model.predict_proba(X_valid_vectorized)
y_valid_pred = np.argmax(y_valid_proba_pred, axis=1)

print("\n--- Final Model Performance on Validation Set ---")


print(f"Accuracy: {accuracy_score(y_valid, y_valid_pred):.4f}")
print(f"F1-score: {f1_score(y_valid, y_valid_pred, average='weighted'):.4f}")
print(f"Test Precision:  {precision_score(y_valid, y_valid_pred, average='weighted'):.4f}")
print(f"Test Recall:  {recall_score(y_valid, y_valid_pred, average='weighted'):.4f}\n")

print("\nClassification Report (Validation):")
print(classification_report(y_test, y_valid))
# Out:
# --- Final Model Performance on Validation Set ---
# Accuracy: 0.8534
# F1-score: 0.8545
# Test Precision:  0.8560
# Test Recall:  0.8534
#
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62      1377
#            1       0.20      0.20      0.20       465
#            2       0.16      0.16      0.16       354
#
#     accuracy                           0.46      2196
#    macro avg       0.33      0.33      0.33      2196
# weighted avg       0.46      0.46      0.46      2196

# %%
### (B) Evaluate the model's performance for Test set

y_test_proba_pred = best_model.predict_proba(X_test_vectorized)
y_test_pred = np.argmax(y_test_proba_pred, axis=1)

print("\n--- Final Model Performance on Test Set ---")
print(f"Accuracy: {accuracy_score(y_test, y_test_pred):.4f}")
print(f"F1-score: {f1_score(y_test, y_test_pred, average='weighted')}")
print(f"Test Precision:  {precision_score(y_test, y_test_pred, average='weighted'):.4f}")
print(f"Test Recall:  {recall_score(y_test, y_test_pred, average='weighted'):.4f}\n")

print("\nClassification Report (Test):")
print(classification_report(y_test, y_test_pred))
# Out:
# --- Final Model Performance on Test Set ---
# Accuracy: 0.8566
# F1-score: 0.8573478889142951
# Test Precision:  0.8583
# Test Recall:  0.8566
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      1377
#            1       0.70      0.74      0.72       465
#            2       0.80      0.79      0.80       354
#
#     accuracy                           0.86      2196
#    macro avg       0.81      0.81      0.81      2196
# weighted avg       0.86      0.86      0.86      2196
